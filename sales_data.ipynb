# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrxdls/Basic_python_prog/blob/main/sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('sales_data.csv')
sales
# Out:
#           Date  Product_ID Product_Category  Quantity_Sold  Price_Per_Unit  \
# 0   2023-01-01        1006             Toys              1      332.230317
# 1   2023-01-02        1003        Furniture             19      288.471216
# 2   2023-01-03        1007      Electronics             10       55.900636
# 3   2023-01-04        1004             Toys             12      190.180743
# 4   2023-01-05        1006         Clothing             15      139.949160
# ..         ...         ...              ...            ...             ...
# 95  2023-04-06        1009             Toys             14      351.027361
# 96  2023-04-07        1008         Clothing             16      210.386943
# 97  2023-04-08        1006      Electronics              8       94.914217
# 98  2023-04-09        1008        Furniture              7       86.654151
# 99  2023-04-10        1007      Electronics              3      132.619020
#
#    Region  Total_Revenue
# 0   South     332.230317
# ...

# %%
sales = pd.read_csv('sales_data.csv')
sales.head()
# Out:
#          Date  Product_ID Product_Category  Quantity_Sold  Price_Per_Unit  \
# 0  2023-01-01        1006             Toys              1      332.230317
# 1  2023-01-02        1003        Furniture             19      288.471216
# 2  2023-01-03        1007      Electronics             10       55.900636
# 3  2023-01-04        1004             Toys             12      190.180743
# 4  2023-01-05        1006         Clothing             15      139.949160
#
#   Region  Total_Revenue
# 0  South     332.230317
# 1  South    5480.953097
# 2   West     559.006362
# 3  North    2282.168922
# 4   West    2099.237402

# %%
sales.dtypes
# Out:
# Date                 object
# Product_ID            int64
# Product_Category     object
# Quantity_Sold         int64
# Price_Per_Unit      float64
# Region               object
# Total_Revenue       float64
# dtype: object

# %%
sales['Date'] = pd.to_datetime(sales['Date'])

# %%
sales.dtypes
# Out:
# Date                datetime64[ns]
# Product_ID                   int64
# Product_Category            object
# Quantity_Sold                int64
# Price_Per_Unit             float64
# Region                      object
# Total_Revenue              float64
# dtype: object

# %%
total_reveneue = sales['Total_Revenue'].sum()
total_reveneue
# Out:
# 241521.33335087914

# %%
np.mean(sales['Quantity_Sold']).round()
# Out:
# 9.0

# %%
top_products = sales.sort_values(by='Total_Revenue', ascending=False).head(3)
top_products
# Out:
#          Date  Product_ID Product_Category  Quantity_Sold  Price_Per_Unit  \
# 22 2023-01-23        1009      Electronics             19      458.283551
# 44 2023-02-14        1009             Toys             19      439.912805
# 6  2023-01-07        1002        Furniture             17      486.775172
#
#    Region  Total_Revenue
# 22  North    8707.387473
# 44  North    8358.343300
# 6   North    8275.177921

# %%
revenue_bar = plt.bar(sales['Product_Category'], sales['Total_Revenue'])
revenue_bar
# Out:
# <BarContainer object of 100 artists>

# %%
revenue_by_region = sales.groupby('Region')['Total_Revenue'].sum()
revenue_by_region
plt.pie(revenue_by_region, labels=revenue_by_region.index, autopct = '%1.1f%%', startangle=90)
plt.title('Revenue by Region')
# Out:
# Text(0.5, 1.0, 'Revenue by Region')
